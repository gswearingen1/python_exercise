# %% [markdown]
# ## IDOH Data Scientist Job Interview: Python Exercise
#
# For this exercise, you will be working with sample data of healthcare patients and details about their visits to facilities. The patient dataset has a row for each patient, and includes age, sex at birth, county, and insurance payer. The encounters dataset has a row for each healthcare visit, along with which patient visited, when they visited, the diagnosis category, and other info. You will be performing various transformations on these datasets and doing some analyses that you would commonly do on the job. Good luck!

# %% [markdown]
# #### Q0. Import libraries

# %% [markdown]
# #### Q1. Retrieve data
#
# URLs for sample healthcare and encounter data are provided below. Retrieve the datasets from these URLs and store them as pandas DataFrames.

# %%
url_patient = 'https://raw.githubusercontent.com/gswearingen1/sample_health_data/refs/heads/main/patients.json'
url_encounter = 'https://raw.githubusercontent.com/gswearingen1/sample_health_data/refs/heads/main/encounters.json'

# %% [markdown]
# #### Q2. Clean datasets
#
# Impute any missing data, check for duplicates, etc.

# %% [markdown]
# #### Q3. Monthly averages
#
# Get monthly averages for length of stay, wait time, and total charges from the encounters dataset.

# %% [markdown]
# #### Q4. Merge data
#
# Merge the encounters dataset with the patients dataset (hint: there should be the same number of rows as there are in the encounters dataset, but with extra columns).

# %% [markdown]
# #### Q5. Visualize data
#
# Create a visual to display the distribution of wait time by facility type.

# %% [markdown]
# #### Q6. Statistical test
#
# Perform a statistical test to see if there is a relationship between urban/rural location and diagnosis category.
